# %% [markdown]
# **Часть 1**

# %% [markdown]
# __1.__ Решить систему уравнений методом Гаусса:
#
# $$\begin{cases}
# x_{1}+x_{2}-x_{3}-2x_{4}=0, \\
# 2x_{1}+x_{2}-x_{3}+x_{4}=-2, \\
# x_{1}+x_{2}-3x_{3}+x_{4}=4.
# \end{cases}$$

# %% [markdown]
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1 & -2\\
# 2 & 1 & -1 & 1\\
# 1 & 1 & -3 & 1
# \end{matrix}\right|
# \begin{matrix}
# 0\\
# -2\\
# 4
# \end{matrix}
# \end{pmatrix}
# \rightarrow
# \begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1 & -2\\
# 0 & -1 & 1 & 5\\
# 0 & 0 & -2 & 3
# \end{matrix}\right|
# \begin{matrix}
# 0\\
# -2\\
# 4
# \end{matrix}
# \end{pmatrix}$<br><br>
# $\begin{cases}
# x_{1}+x_{2}-x_{3}-2x_{4}=0, \\
# -x_{2}+x_{3}+5x_{4}=-2, \\
# -2x_{3}+3x_{4}=4.
# \end{cases}$<br><br>
# $\begin{cases}
# x_{4}=C, \\
# x_{3}=\frac{3}{2}C-2, \\
# x_{2}=6.5C, \\
# x_{1}=-2-3C.
# \end{cases}$<br><br>
# $C=0, x_{3}=-2, x_{2}=0, x_{1}=-2$

# %% [markdown]
# __2.__ Проверить на совместность и выяснить, сколько решений будет иметь система линейных уравнений:
#
#    а) $\begin{cases}
# 3x_{1}-x_{2}+x_{3}=4, \\
# 2x_{1}-5x_{2}-3x_{3}=-17, \\
# x_{1}+x_{2}-x_{3}=0;
# \end{cases}$
#
# Ответ: Совместная, одно решение(определённая). Т.к. n не равно m, линейно независимые столбцы и строки
#
#    б) $\begin{cases}
# 2x_{1}-4x_{2}+6x_{3}=1, \\
# x_{1}-2x_{2}+3x_{3}=-2, \\
# 3x_{1}-6x_{2}+9x_{3}=5;
# \end{cases}$
#
# Ответ: Несовместная, решений нет. Т.к. линейно независимые столбцы и строки, вектор свободных членов в другом подпространстве
#
#    в) $\begin{cases}
# x_{1}+2x_{2}+5x_{3}=4, \\
# 3x_{1}+x_{2}-8x_{3}=-2.
# \end{cases}$
#
# Ответ: Совместная, множество решений. Т.к. число уравнений меньше числа неизвестных

# %% [markdown]
# __3.__ Проверить на совместность и выяснить, сколько решений будет иметь система линейных уравнений, заданная расширенной матрицей
#
# $$\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 3 & -2 & 4\\
# 0 & 5 & 0 & 1\\
# 0 & 0 & 3 & 0\\
# 0 & 0 & 0 & 2
# \end{matrix}\right|
# \begin{matrix}
# 3\\
# 2\\
# 4\\
# 1
# \end{matrix}
# \end{pmatrix}.$$
#
# Ответ: Совместная, одно решение(определённая). Т.к. ранги равны и равны n

# %% [markdown]
# __4.__ Дана система линейных уравнений, заданная расширенной матрицей
#
# Найти соотношение между параметрами $a$, $b$ и $c$, при которых система является несовместной.
#
# $$\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 4 & 5 & 6\\
# 7 & 8 & 9
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b\\
# c
# \end{matrix}
# \end{pmatrix}
# \rightarrow
# \begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 2 & 1 & 0\\
# 0 & 0 & 0
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b-2a\\
# c-a-2b=0
# \end{matrix}
# \end{pmatrix}
# $$
#
# Ответ: $c-a-2b\neq0$

# %% [markdown]
# **Часть 2**

# %% [markdown]
# __1.__ Решить систему уравнений методом Крамера:
#
#    а) $\begin{cases}
# x_{1}-2x_{2}=1 \\
# 3x_{1}-4x_{2}=7
# \end{cases}$
#
# $detA=\begin{vmatrix}
# 1 & -2\\
# 3 & -4
# \end{vmatrix}=
# -4+6=2\neq 0$
#
# $detA_{1}=\begin{vmatrix}
# 1 & -2\\
# 7 & -4
# \end{vmatrix}=
# -4+14=10$
#
# $detA_{2}=\begin{vmatrix}
# 1 & 1\\
# 3 & 7
# \end{vmatrix}=
# 7-3=4$
#
# $x_{1}=\frac{10}{2}=5$
#
# $x_{2}=\frac{4}{2}=2$
#
#    б) $\begin{cases}
# 2x_{1}-x_{2}+5x_{3}=10 \\
# x_{1}+x_{2}-3x_{3}=-2 \\
# 2x_{1}+4x_{2}+x_{3}=1
# \end{cases}$
#
# $detA=\begin{vmatrix}
# 2 & -1 & 5\\
# 1 & 1 & -3\\
# 2 & 4 & 1
# \end{vmatrix}=
# 2+6+20-10+1+24=43\neq 0$
#
# $detA_{1}=\begin{vmatrix}
# 10 & -1 & 5\\
# -2 & 1 & -3\\
# 1 & 4 & 1
# \end{vmatrix}=
# 10+3-40-5-2+120=86$
#
# $detA_{2}=\begin{vmatrix}
# 2 & 10 & 5\\
# 1 & -2 & -3\\
# 2 & 1 & 1
# \end{vmatrix}=
# -4-60+5+20-10+6=-43$
#
# $detA_{3}=\begin{vmatrix}
# 2 & -1 & 10\\
# 1 & 1 & -2\\
# 2 & 4 & 1
# \end{vmatrix}=
# 2+4+40-20+16+1=43$
#
# $x_{1}=\frac{86}{43}=2$
#
# $x_{2}=\frac{-43}{43}=-1$
#
# $x_{23}=\frac{43}{43}=1$

# %% [markdown]
# __2*.__ Найти $L$-матрицу $LU$-разложения для матрицы коэффициентов:
#
#    а)$$\begin{pmatrix}
# 1 & 2 & 4 \\
# 2 & 9 & 12 \\
# 3 & 26 & 30
# \end{pmatrix}$$
#
# $U=\begin{pmatrix}
# 1 & 2 & 4 \\
# 0 & 5 & 4 \\
# 0 & 0 & 2
# \end{pmatrix}$
#
# $L=\begin{pmatrix}
# 1 & 0 & 0 \\
# 2 & 1 & 0 \\
# 3 & 4 & 1
# \end{pmatrix}$
#
#    б)$$\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 2 & 5 & 8 & 9\\
# 3 & 18 & 29 & 18\\
# 4 & 22 & 53 & 33
# \end{pmatrix}$$
#
# $U=\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 0 & 3 & 4 & 1\\
# 0 & 0 & 3 & 1\\
# 0 & 0 & 0 & 4
# \end{pmatrix}$
#
# $L=\begin{pmatrix}
# 1 & 0 & 0 & 0\\
# 2 & 1 & 0 & 0\\
# 3 & 5 & 1 & 0\\
# 4 & 6 & 7 & 1
# \end{pmatrix}$

# %% [markdown]
# __3*.__ Решить систему линейных уравнений методом $LU$-разложения
#
# $$\begin{cases}
# 2x_{1}+x_{2}+3x_{3}=1 \\
# 11x_{1}+7x_{2}+5x_{3}=-6 \\
# 9x_{1}+8x_{2}+4x_{3}=-5
# \end{cases}$$
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 2 & 1 & 1 \\
# 11 & 7 & 5 \\
# 9 & 8 & 4
# \end{matrix}\right|
# \begin{matrix}
# 1\\
# -6\\
# -5
# \end{matrix}
# \end{pmatrix}$
#
# $U=\begin{pmatrix}
# 2 & 1 & 1 \\
# 0 & 1.5 & -0.5 \\
# 0 & 0 & \frac{2}{3}
# \end{pmatrix}$
#
# $L=\begin{pmatrix}
# 1 & 0 & 0 \\
# 5.5 & 1 & 0 \\
# 4.5 & \frac{7}{3} & 1
# \end{pmatrix}$
#
# Ly=y
#
# $\begin{cases}
# y_{1}=1, \\
# y_{2}=-11.5, \\
# y_{3}=\frac{52}{3};
# \end{cases}$
#
# Ux=y
#
# $\begin{cases}
# x_{1}=-13, \\
# x_{2}=1, \\
# x_{3}=26;
# \end{cases}$

# %% [markdown]
# __4*.__ Решить систему линейных уравнений методом Холецкого
#
# $$\begin{cases}
# 81x_{1}-45x_{2}+45x_{3}=531 \\
# -45x_{1}+50x_{2}-15x_{3}=-460 \\
# 45x_{1}-15x_{2}+38x_{3}=193
# \end{cases}$$

# %% [markdown]
# $\begin{pmatrix}
# \left.\begin{matrix}
# 81 & -45 & 45 \\
# -45 & 50 & -15 \\
# 45 & -15 & 38
# \end{matrix}\right|
# \begin{matrix}
# 531\\
# -460\\
# 193
# \end{matrix}
# \end{pmatrix}$
#
# $l_{11}=9$ $l_{21}=-5$ $l_{31}=5$
#
# $l_{22}=5$ $l_{32}=2$ $l_{33}=3$
#
# $L=\begin{pmatrix}
# 9 & 0 & 0 \\
# -5 & 5 & 0 \\
# 5 & 2 & 3
# \end{pmatrix}$
#
# $L^{T}=\begin{pmatrix}
# 9 & -5 & 5 \\
# 0 & 5 & 2 \\
# 0 & 0 & 3
# \end{pmatrix}$
#
# Ly=b
#
# $\begin{cases}
# y_{1}=59, \\
# y_{2}=-33, \\
# y_{3}=-12;
# \end{cases}$
#
# $L^{T}$x=y
#
# $\begin{cases}
# x_{1}=6, \\
# x_{2}=-5, \\
# x_{3}=-4;
# \end{cases}$

# %% [markdown]
# __5*.__ Написать на Python программу с реализацией одного из изученных алгоритмов решения СЛАУ.

# %%
import numpy as np
A = np.array([[81, -45, 45], [-45, 50, -15], [45, -15, 38]])
b = np.array([531, -460, 193])

# %%
detA = np.linalg.det(A)
A1 = np.column_stack([b, A[:,1:]])
detA1 = np.linalg.det(A1)
A2 = np.column_stack([A[:,0], b, A[:,2]])
detA2 = np.linalg.det(A2)
A3 = np.column_stack([A[:,0], A[:,1], b])
detA3 = np.linalg.det(A3)
X1 = detA1/detA
X2 = detA2/detA
X3 = detA3/detA
print(f'X1={X1:.1f}, X2={X2:.1f}, X3={X3:.1f}')
# Out:
# X1=6.0, X2=-5.0, X3=-4.0
